# %%
import matplotlib.pyplot as plt
import numpy as np

# Data points
metrics = ["Accuracy", "Bias and Fairness", "Clarity", "Coherence", "Completeness", "Conciseness", "Hallucination"]
min_values = [0.87, 0.5, 1, 0.85, 0.67, 0.65, 0.03]
max_values = [0.94, 0.67, 1, 0.95, 0.83, 0.83, 0.21]

# Plot settings
x = np.arange(len(metrics))
width = 0.4

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width/2, min_values, width, label='Min Values')
bars2 = ax.bar(x + width/2, max_values, width, label='Max Values')

# Labels, title, and custom x-axis tick labels
ax.set_ylabel('Values')
ax.set_title('Archicture 1 (Chunking Architecture)')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.set_ylim(0, 1.1)
ax.legend()

# Add value labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars1)
add_labels(bars2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data points
metrics = ["Accuracy", "Bias And Fairness", "Clarity", "Coherence", "Completeness", "Conciseness", "Hallucination"]
min_values = [0.9, 0.8, 0.95, 0.75, 0.67, 0.6, 0.1]
max_values = [1, 0.8, 0.95, 0.95, 0.75, 0.8, 0.2]

# Plot settings
x = np.arange(len(metrics))
width = 0.4

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width/2, min_values, width, label='Min Values')
bars2 = ax.bar(x + width/2, max_values, width, label='Max Values')

# Labels, title, and custom x-axis tick labels
ax.set_ylabel('Values')
ax.set_title('Archicture 2')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.set_ylim(0, 1.1)
ax.legend()

# Add value labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars1)
add_labels(bars2)

plt.show()

# %%
samples = np.arange(1, 13)
arch1_bias_fairness = [0.67, 0.66, 0.58, 0.6, 0.5, 0.67, 0.63, 0.67, 0.6, 0.6, 0.63, 0.63]
arch1_completeness = [0.76, 0.75, 0.67, 0.65, 0.83, 0.76, 0.76, 0.84, 0.8, 0.78, 0.76, 0.76]
arch2_bias_fairness = [0.80, 0.90, 0.95, 0.80, 0.80, 0.80, 0.80, 0.85, 0.80, 0.80, 0.80]
arch2_completeness = [0.68, 0.75, 0.68, 0.65, 0.68, 0.68, 0.75, 0.68, 0.65, 0.65, 0.65]

# Creating subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# Plot for Bias and Fairness
ax1.plot(samples, arch1_bias_fairness, marker='o', label='Architecture 1')
ax1.plot(samples[:11], arch2_bias_fairness, marker='o', label='Architecture 2')
ax1.set_ylabel('Bias and Fairness')
ax1.set_title('Bias and Fairness Across Samples')
ax1.legend()
ax1.grid(True)

# Plot for Completeness
ax2.plot(samples, arch1_completeness, marker='o', label='Architecture 1')
ax2.plot(samples[:11], arch2_completeness, marker='o', label='Architecture 2')
ax2.set_ylabel('Completeness')
ax2.set_xlabel('Samples')
ax2.set_title('Completeness Across Samples')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# *Exemple output*:
#
# Architecture 2:- *Availability:*
#   - *Detailed Summary:*
#     The need for continuous availability of IT services is implied throughout the RFP.
#   - *References from RFP text:*
#     - "Business continuity; Emergency Preparedness..."*
# Architecture 1:
# *Project Resources*:
#   - The Contractor is responsible for providing all necessary documents, materials, and data, including confidential information, developed during the contract. They must ensure compliance with applicable laws and regulations, including obtaining necessary licenses and permits. Additionally, the Contractor must maintain insurance coverage at their own expense, naming H.O.C. as an additional insured, and provide a certificate of insurance prior to contract award. The Contractor is also required to comply with ethics provisions and is responsible for indemnifying H.O.C. against any losses or damages resulting from their negligence or failure to fulfill contractual obligations. Time is emphasized as critical in the execution of the contract, and the Contractor must adhere to immigration laws regarding the employment of individuals.
